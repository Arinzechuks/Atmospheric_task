# %% [markdown]
# <a href="https://colab.research.google.com/github/Arinzechuks/Atmospheric_task/blob/main/TempMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Arinzechuks/Atmospheric_task.git
# !cd Atmospheric_task
# !dir
# Out:
# fatal: destination path 'Atmospheric_task' already exists and is not an empty directory.

# %%
import pandas as pd

xx = pd.read_csv('Atmos41.csv')    # csv files
#xx = pd.read_excel('Atmos41.xlsx')

list(xx)  # get the list of column names
# Out:
#         Date  Time  Temp_Out  Humidity_out  Dew_Pt.  Wind_Speed  \
# 0   1/1/2007  0:30      23.0            34      6.3         2.2
# 1   1/1/2007  1:00      23.1            33      5.9         2.7
# 2   1/1/2007  1:30      22.9            33      5.8         2.7
# 3   1/1/2007  2:00      22.9            33      5.8         3.1
# 4   1/1/2007  2:30      22.6            34      5.9         2.7
# 5   1/1/2007  3:00      22.7            32      5.1         2.7
# 6   1/1/2007  3:30      22.6            32      5.1         2.7
# 7   1/1/2007  4:00      22.5            32      5.0         2.2
# 8   1/1/2007  4:30      22.2            34      5.6         3.1
# 9   1/1/2007  5:00      21.2            37      5.9         3.1
# 10  1/1/2007  5:30      20.9            37      5.6         4.9
# 11  1/1/2007  6:00      20.7            37      5.5         4.9
# 12  1/1/2007  6:30      20.7            35      4.6         6.3
# 13  1/1/2007  7:00      19.8            39      5.4         6.3
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the data
x = np.arange(0, 10, 0.1)
y = np.sin(x)

# Plot the data
plt.plot(x, y)

# Set the x-axis and y-axis labels
plt.xlabel('x')
plt.ylabel('y')

# Set the title of the plot
plt.title('A Sine Wave')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data
time = [00:30, 01:00, 01:30, 02:00, 02:30, 03:00, 03:30, 04:00, 04:30, 05:00, 05:30, 06:00, 06:30, 07:00, 07:30, 08:00, 08:30, 09:00]
temp_out = [23, 23.1, 22.9, 22.9, 22.6, 22.7, 22.6, 22.5, 22.2, 21.2, 20.9, 20.7, 20.7, 19.8, 19.6, 19.1, 19.6, 20.3]
humidity_out = [34, 33, 33, 33, 34, 32, 32, 32, 34, 37, 37, 37, 35, 39, 39, 40, 37, 37]
dew_pt = [6.3, 5.9, 5.8, 5.8, 5.9, 5.1, 5.1, 5, 5.6, 5.9, 5.6, 5.5, 4.6, 5.4, 5.3, 5.2, 5.1, 5.1]
wind_speed = [2.2, 2.7, 2.7, 2.7, 3.1, 2.7, 2.7, 2.2, 3.1, 3.1, 4.9, 4.9, 6.3, 6.3, 5.8, 4.5, 4.5]
pressure_bar = [976.7, 976.4, 976.2, 975.8, 975.6, 975.4, 975.4, 975.1, 975.3, 975.6, 975.6, 976.2, 976.3, 976.6, 977, 977.4, 977.4]
heat_index = [22.1, 22.1, 21.8, 21.9, 21.4, 21.4, 21.3, 21.2, 20.8, 19.6, 19.3, 19.2, 19, 18.3, 18.2, 17.7, 18.1, 18.7]

# Create the figure
fig, ax = plt.subplots()

# Plot the data
ax.plot(time, temp_out, label="Temperature")
ax.plot(time, humidity_out, label="Humidity")
ax.plot(time, dew_pt, label="Dew Point")
ax.plot(time, wind_speed, label="Wind Speed")
ax.plot(time, pressure_bar, label="Pressure")
ax.plot(time, heat_index, label="Heat Index")

# Set the x-axis and y-axis labels
ax.set_xlabel("Time")
ax.set_ylabel("Value")

# Add a legend
ax.legend()

# Show the plot
plt.show()
# Out:
#   File "<ipython-input-36-a040d9209acb>", line 4
#     time = [00:30, 01:00, 01:30, 02:00, 02:30, 03:00, 03:30, 04:00, 04:30, 05:00, 05:30, 06:00, 06:30, 07:00, 07:30, 08:00, 08:30, 09:00]
#                    ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
